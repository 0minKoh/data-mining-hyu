# %% [markdown]
# # 보팅과 랜덤 포레스트 Lab

# %% [markdown]
# 1. churnTrain.csv, churnTest.csv 파일을 읽어서 각각 churnTrain_df, churnTest_df 데이터 프레임에 저장하시오.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import warnings
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
churnTrain_df = pd.read_csv('../../asset/churnTrain.csv')
churnTrain_df
# Out:
#      state  account_length      area_code international_plan voice_mail_plan  \
# 0       KS             128  area_code_415                 no             yes
# 1       OH             107  area_code_415                 no             yes
# 2       NJ             137  area_code_415                 no              no
# 3       OH              84  area_code_408                yes              no
# 4       OK              75  area_code_415                yes              no
# ...    ...             ...            ...                ...             ...
# 3328    AZ             192  area_code_415                 no             yes
# 3329    WV              68  area_code_415                 no              no
# 3330    RI              28  area_code_510                 no              no
# 3331    CT             184  area_code_510                yes              no
# 3332    TN              74  area_code_415                 no             yes
#
#       number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       total_night_minutes  total_night_calls  total_night_charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       total_intl_minutes  total_intl_calls  total_intl_charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       number_customer_service_calls churn
# 0                                 1    no
# 1                                 1    no
# 2                                 0    no
# 3                                 2    no
# 4                                 3    no
# ...                             ...   ...
# 3328                              2    no
# 3329                              3    no
# 3330                              2    no
# 3331                              2    no
# 3332                              0    no
#
# [3333 rows x 20 columns]

# %%
churnTest_df = pd.read_csv('../../asset/churnTest.csv')
churnTest_df
# Out:
#      state  account_length      area_code international_plan voice_mail_plan  \
# 0       HI             101  area_code_510                 no              no
# 1       MT             137  area_code_510                 no              no
# 2       OH             103  area_code_408                 no             yes
# 3       NM              99  area_code_415                 no              no
# 4       SC             108  area_code_415                 no              no
# ...    ...             ...            ...                ...             ...
# 1662    HI              50  area_code_408                 no             yes
# 1663    WV             152  area_code_415                 no              no
# 1664    DC              61  area_code_415                 no              no
# 1665    DC             109  area_code_510                 no              no
# 1666    VT              86  area_code_415                 no             yes
#
#       number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                         0               70.9              123
# 1                         0              223.6               86
# 2                        29              294.7               95
# 3                         0              216.8              123
# 4                         0              197.4               78
# ...                     ...                ...              ...
# 1662                     40              235.7              127
# 1663                      0              184.2               90
# 1664                      0              140.6               89
# 1665                      0              188.8               67
# 1666                     34              129.4              102
#
#       total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0                12.05              211.9               73             18.01
# 1                38.01              244.8              139             20.81
# 2                50.10              237.3              105             20.17
# 3                36.86              126.4               88             10.74
# 4                33.56              124.0              101             10.54
# ...                ...                ...              ...               ...
# 1662             40.07              223.0              126             18.96
# 1663             31.31              256.8               73             21.83
# 1664             23.90              172.8              128             14.69
# 1665             32.10              171.7               92             14.59
# 1666             22.00              267.1              104             22.70
#
#       total_night_minutes  total_night_calls  total_night_charge  \
# 0                   236.0                 73               10.62
# 1                    94.2                 81                4.24
# 2                   300.3                127               13.51
# 3                   220.6                 82                9.93
# 4                   204.5                107                9.20
# ...                   ...                ...                 ...
# 1662                297.5                116               13.39
# 1663                213.6                113                9.61
# 1664                212.4                 97                9.56
# 1665                224.4                 89               10.10
# 1666                154.8                100                6.97
#
#       total_intl_minutes  total_intl_calls  total_intl_charge  \
# 0                   10.6                 3               2.86
# 1                    9.5                 7               2.57
# 2                   13.7                 6               3.70
# 3                   15.7                 2               4.24
# 4                    7.7                 4               2.08
# ...                  ...               ...                ...
# 1662                 9.9                 5               2.67
# 1663                14.7                 2               3.97
# 1664                13.6                 4               3.67
# 1665                 8.5                 6               2.30
# 1666                 9.3                16               2.51
#
#       number_customer_service_calls churn
# 0                                 3    no
# 1                                 0    no
# 2                                 1    no
# 3                                 1    no
# 4                                 2    no
# ...                             ...   ...
# 1662                              2    no
# 1663                              3   yes
# 1664                              1    no
# 1665                              0    no
# 1666                              0    no
#
# [1667 rows x 20 columns]

# %% [markdown]
# 2. 두 데이터 프레임에서 state와 area_code 컬럼을 제거하시오.

# %%
churnTrain_df.drop(['state','area_code'],axis=1,inplace=True)
churnTrain_df
# Out:
#       account_length international_plan voice_mail_plan  \
# 0                128                 no             yes
# 1                107                 no             yes
# 2                137                 no              no
# 3                 84                yes              no
# 4                 75                yes              no
# ...              ...                ...             ...
# 3328             192                 no             yes
# 3329              68                 no              no
# 3330              28                 no              no
# 3331             184                yes              no
# 3332              74                 no             yes
#
#       number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       total_night_minutes  total_night_calls  total_night_charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       total_intl_minutes  total_intl_calls  total_intl_charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       number_customer_service_calls churn
# 0                                 1    no
# 1                                 1    no
# 2                                 0    no
# 3                                 2    no
# 4                                 3    no
# ...                             ...   ...
# 3328                              2    no
# 3329                              3    no
# 3330                              2    no
# 3331                              2    no
# 3332                              0    no
#
# [3333 rows x 18 columns]

# %%
churnTest_df.drop(['state','area_code'],axis=1,inplace=True)
churnTest_df
# Out:
#       account_length international_plan voice_mail_plan  \
# 0                101                 no              no
# 1                137                 no              no
# 2                103                 no             yes
# 3                 99                 no              no
# 4                108                 no              no
# ...              ...                ...             ...
# 1662              50                 no             yes
# 1663             152                 no              no
# 1664              61                 no              no
# 1665             109                 no              no
# 1666              86                 no             yes
#
#       number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                         0               70.9              123
# 1                         0              223.6               86
# 2                        29              294.7               95
# 3                         0              216.8              123
# 4                         0              197.4               78
# ...                     ...                ...              ...
# 1662                     40              235.7              127
# 1663                      0              184.2               90
# 1664                      0              140.6               89
# 1665                      0              188.8               67
# 1666                     34              129.4              102
#
#       total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0                12.05              211.9               73             18.01
# 1                38.01              244.8              139             20.81
# 2                50.10              237.3              105             20.17
# 3                36.86              126.4               88             10.74
# 4                33.56              124.0              101             10.54
# ...                ...                ...              ...               ...
# 1662             40.07              223.0              126             18.96
# 1663             31.31              256.8               73             21.83
# 1664             23.90              172.8              128             14.69
# 1665             32.10              171.7               92             14.59
# 1666             22.00              267.1              104             22.70
#
#       total_night_minutes  total_night_calls  total_night_charge  \
# 0                   236.0                 73               10.62
# 1                    94.2                 81                4.24
# 2                   300.3                127               13.51
# 3                   220.6                 82                9.93
# 4                   204.5                107                9.20
# ...                   ...                ...                 ...
# 1662                297.5                116               13.39
# 1663                213.6                113                9.61
# 1664                212.4                 97                9.56
# 1665                224.4                 89               10.10
# 1666                154.8                100                6.97
#
#       total_intl_minutes  total_intl_calls  total_intl_charge  \
# 0                   10.6                 3               2.86
# 1                    9.5                 7               2.57
# 2                   13.7                 6               3.70
# 3                   15.7                 2               4.24
# 4                    7.7                 4               2.08
# ...                  ...               ...                ...
# 1662                 9.9                 5               2.67
# 1663                14.7                 2               3.97
# 1664                13.6                 4               3.67
# 1665                 8.5                 6               2.30
# 1666                 9.3                16               2.51
#
#       number_customer_service_calls churn
# 0                                 3    no
# 1                                 0    no
# 2                                 1    no
# 3                                 1    no
# 4                                 2    no
# ...                             ...   ...
# 1662                              2    no
# 1663                              3   yes
# 1664                              1    no
# 1665                              0    no
# 1666                              0    no
#
# [1667 rows x 18 columns]

# %% [markdown]
# 3. 두 데이터 프레임에서 목표 변수인 churn의 'yes'를 1로 'no'를 0으로 치환하시오.

# %%
churnTrain_df['churn']=churnTrain_df['churn'].apply(lambda x: 1 if x=='yes' else 0)
churnTest_df['churn']=churnTest_df['churn'].apply(lambda x: 1 if x=='yes' else 0)
churnTest_df['churn'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='churn'>

# %% [markdown]
# 4. 두 데이터 프레임에서 international_plan, voice_mail_plan의 ‘yes’값을 1로 ‘no’값을 0으로 치환하시오.

# %%
churnTrain_df['international_plan']=churnTrain_df['international_plan'].apply(lambda x: 1 if x=='yes' else 0)
churnTrain_df['voice_mail_plan']=churnTrain_df['voice_mail_plan'].apply(lambda x: 1 if x=='yes' else 0)
churnTest_df['international_plan']=churnTest_df['international_plan'].apply(lambda x: 1 if x=='yes' else 0)
churnTest_df['voice_mail_plan']=churnTest_df['voice_mail_plan'].apply(lambda x: 1 if x=='yes' else 0)
churnTest_df
# Out:
#       account_length  international_plan  voice_mail_plan  \
# 0                101                   0                0
# 1                137                   0                0
# 2                103                   0                1
# 3                 99                   0                0
# 4                108                   0                0
# ...              ...                 ...              ...
# 1662              50                   0                1
# 1663             152                   0                0
# 1664              61                   0                0
# 1665             109                   0                0
# 1666              86                   0                1
#
#       number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                         0               70.9              123
# 1                         0              223.6               86
# 2                        29              294.7               95
# 3                         0              216.8              123
# 4                         0              197.4               78
# ...                     ...                ...              ...
# 1662                     40              235.7              127
# 1663                      0              184.2               90
# 1664                      0              140.6               89
# 1665                      0              188.8               67
# 1666                     34              129.4              102
#
#       total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0                12.05              211.9               73             18.01
# 1                38.01              244.8              139             20.81
# 2                50.10              237.3              105             20.17
# 3                36.86              126.4               88             10.74
# 4                33.56              124.0              101             10.54
# ...                ...                ...              ...               ...
# 1662             40.07              223.0              126             18.96
# 1663             31.31              256.8               73             21.83
# 1664             23.90              172.8              128             14.69
# 1665             32.10              171.7               92             14.59
# 1666             22.00              267.1              104             22.70
#
#       total_night_minutes  total_night_calls  total_night_charge  \
# 0                   236.0                 73               10.62
# 1                    94.2                 81                4.24
# 2                   300.3                127               13.51
# 3                   220.6                 82                9.93
# 4                   204.5                107                9.20
# ...                   ...                ...                 ...
# 1662                297.5                116               13.39
# 1663                213.6                113                9.61
# 1664                212.4                 97                9.56
# 1665                224.4                 89               10.10
# 1666                154.8                100                6.97
#
#       total_intl_minutes  total_intl_calls  total_intl_charge  \
# 0                   10.6                 3               2.86
# 1                    9.5                 7               2.57
# 2                   13.7                 6               3.70
# 3                   15.7                 2               4.24
# 4                    7.7                 4               2.08
# ...                  ...               ...                ...
# 1662                 9.9                 5               2.67
# 1663                14.7                 2               3.97
# 1664                13.6                 4               3.67
# 1665                 8.5                 6               2.30
# 1666                 9.3                16               2.51
#
#       number_customer_service_calls  churn
# 0                                 3      0
# 1                                 0      0
# 2                                 1      0
# 3                                 1      0
# 4                                 2      0
# ...                             ...    ...
# 1662                              2      0
# 1663                              3      1
# 1664                              1      0
# 1665                              0      0
# 1666                              0      0
#
# [1667 rows x 18 columns]

# %% [markdown]
# 5. 입력변수와 출력변수를 구분하여 각각을 X_train, y_train, X_test, y_test를 만들시오.

# %%
X_train = churnTrain_df.iloc[:, :-1]
y_train = churnTrain_df.iloc[:, -1]
X_test = churnTest_df.iloc[:, :-1]
y_test = churnTest_df.iloc[:, -1]

# %% [markdown]
# !!
# 6. 의사결정나무, 로지스틱 회귀분석, kNN으로 이루어진 보팅 분류기를 만들어서 성능을 평가하시오.

# %%
# Ensemble
from sklearn.ensemble import VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# Metrics
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

def evalPerf(pred, y_test):
  eval_accuracy_score = accuracy_score(pred, y_test)
  eval_recall_score = recall_score(pred, y_test)
  eval_precision_score = precision_score(pred, y_test)
  eval_f1_score = f1_score(pred, y_test)
  print("accuracy_score: {0:.4f}, recall_score: {1:.4f}, precision_score: {2:.4f}, f1_score: {3:.4f}".format(eval_accuracy_score, eval_recall_score, eval_precision_score, eval_f1_score))

dt_clf = DecisionTreeClassifier()
lr = LogisticRegression()
knn = KNeighborsClassifier(n_neighbors=8)

vo_clf = VotingClassifier(estimators=[('DT', dt_clf), ('LR', lr), ('KNN', knn)], voting='soft')
vo_clf.fit(X_train, y_train)
pred = vo_clf.predict(X_test)
evalPerf(pred, y_test)
# Out:
# /Users/sohyunwoo/.pyenv/versions/data-analysis/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# accuracy_score: 0.9112, recall_score: 0.9130, precision_score: 0.3750, f1_score: 0.5316

# %% [markdown]
# 7. 랜덤 포레스트 모델을 생성하여 성능을 평가하시오.

# %%
from sklearn.ensemble import RandomForestClassifier

rf_clf = RandomForestClassifier()
rf_clf.fit(X_train, y_train)
rf_pred = rf_clf.predict(X_test)

evalPerf(rf_pred, y_test)
# Out:
# accuracy_score: 0.9598, recall_score: 0.9701, precision_score: 0.7232, f1_score: 0.8286

# %% [markdown]
# 8. 입력 변수의 중요도를 가시화 하시오.

# %%
X_train.columns
# Out:
# Index(['account_length', 'international_plan', 'voice_mail_plan',
#        'number_vmail_messages', 'total_day_minutes', 'total_day_calls',
#        'total_day_charge', 'total_eve_minutes', 'total_eve_calls',
#        'total_eve_charge', 'total_night_minutes', 'total_night_calls',
#        'total_night_charge', 'total_intl_minutes', 'total_intl_calls',
#        'total_intl_charge', 'number_customer_service_calls'],
#       dtype='object')

# %%
import seaborn as sns

rf_fi = rf_clf.feature_importances_
# print(rf_fi)
rf_fi_series = pd.Series(data=rf_fi, index=X_train.columns).sort_values(ascending=False)
sns.barplot(y=rf_fi_series.index, x=rf_fi_series.values)
plt.show()
