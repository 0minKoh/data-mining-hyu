# %% [markdown]
# # 자료형

# %% [markdown]
# 파이썬 첫 번째 코드

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## 숫자형

# %%
a=123
b= -3.14
c=1+2j

# %%
print(a)
print(b)
print(c)
# Out:
# 123
# -3.14
# (1+2j)

# %% [markdown]
# ## 문자형

# %%
a = "Hello World"
b = 'Python!!'
c = """
Hello
World
# !!
"""
d= '''
Python
Python
Python
'''

# %%
print(a)
print(b)
print(c)
print(d)
# Out:
# Hello World
# Python!!
#
# Hello
# World
# !!
#
#
# Python
# Python
# Python

# %%
print(a+b)
print(a*2)
# Out:
# Hello WorldPython!!
# Hello WorldHello World

# %% [markdown]
# ### 인덱싱과 슬라이싱 (문자열)
#
# ```python
# string[i]
# string[a:b+1] # a~b
# ```

# %%
a = "Python"
print(a[0])
print(a[-1])
print(a[0:4])
print(a[:3])
print(a[0:3])
print(a[:-2])
print(a[3:])
print(a[3:6])
# Out:
# P
# n
# Pyth
# Pyt
# Pyt
# Pyth
# hon
# hon

# %% [markdown]
# ## 불리안

# %%
a=True
b=False

# %%
print(a)
print(b)
# Out:
# True
# False

# %%
# True = 1, False = 0
print(int(a))
print(int(b))
# Out:
# 1
# 0

# %% [markdown]
# ## 리스트

# %%
a = []
b = [1, 2, 3, 5]
c = ['Life','is','Beautiful']
d = [1,2,'Life',3,'is']
e = [1,2,['Life','is','Beautiful']]
print(b[0])
print(c[-2])
print(d[1:3])
print(e[2][0])
# Out:
# 1
# is
# [2, 'Life']
# Life

# %% [markdown]
# ## 튜플
#
# b = (1,) 한 개의 원소를 쓸 때 항상 콤마를 써주어야 함
#
# 콤마를 써주지 않으면, Int로 인식함
#
# 괄호를 생략할 수 있음

# %%
a=()
b= (1,)
c=1,2,3
c[1:2]
print(b+c)
print(c*2)
# Out:
# (1, 1, 2, 3)
# (1, 2, 3, 1, 2, 3)

# %% [markdown]
# ## 딕셔너리

# %%
dic={'name':'kim','age':25,'tel':'2000-1234'}
print(dic['name']) ## 인덱싱으로 접근
print(dic.get('name')) ## .get() 메소드로 접근
# Out:
# kim
# kim

# %%
dic[0] # 딕셔너리는 순서가 없기 때문에 Error 발생
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24516/3912514468.py in <module>
# ----> 1 dic[0]
#
# KeyError: 0

# %% [markdown]
# ## Set (집합)
#
# 집합 내의 요소는 중복을 허용하지 않음

# %%
s1=set([1,2,3,3]) ## set(리스트)
print(s1)
# Out:
# {1, 2, 3}
