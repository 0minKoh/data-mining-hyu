# %% [raw]
# Boston housing  데이터를 이용해서 다음을 수행하시오.

# %% [raw]
# - matplotlib을 이용하여 다음을 수행하시오.

# %%
import pandas as pd
import os


boston_df = pd.read_csv('../../asset/boston_housing.csv')
boston_df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
import matplotlib.pyplot as plt

# %% [raw]
# 1.  ‘medv’값에 대한 히스토그램을 그리시오.

# %%
plt.hist(boston_df['medv']) ## 연속형 값에 대해 범주화됨
plt.show()

# %% [raw]
# 2.  ‘medv’값에 대한 박스플랏을 그리시오.

# %%
plt.boxplot(boston_df['medv'])
plt.show()

# %% [raw]
# 3.‘chas’값에 대한 바 차트를 그리시오.

# %%
plt.bar(boston_df['chas'].value_counts().index, boston_df['chas'].value_counts().values)
# Out:
# <BarContainer object of 2 artists>

# %% [raw]
# 4.‘chas’ 값별로 ‘medv’값에 대한 박스 플랏을 그리시오.

# %%
medv_when_chas_1 = boston_df.loc[boston_df['chas'] == 0, 'medv']
medv_when_chas_2 = boston_df.loc[boston_df['chas'] == 1, 'medv']
plt.boxplot([medv_when_chas_1, medv_when_chas_2], labels=['Near Charles','Not Near Charles'])
plt.show()

# %% [raw]
# 5. x축을 ‘crim’, y축을 ‘medv’로 해서 산점도를 그리시오.

# %%
plt.scatter(x=boston_df['crim'], y=boston_df['medv'])
plt.show()

# %% [raw]
# 6. x축을 ‘crim’, y축을 ‘medv’로 해서 산점도를 그리시오. 단 chas 값이 0이면 빨간색으로, 1이면 초록색으로 점을 표시하시오.

# %%
colors = {0: 'r', 1: 'g'}

for i in range(len(boston_df.index)):
  plt.scatter(x=boston_df['crim'][i], y=boston_df['medv'][i], color=colors[boston_df['chas'][i]])
plt.show()

# %% [raw]
# 7.‘medv’값을 레코드 순으로 라인 차트를 그리시오.

# %%
plt.plot(boston_df['medv'])
plt.show()

# %% [raw]
# 8. 전체 변수들에 대한 히트맵을 그리시오.

# %%
import numpy as np

plt_corr = boston_df.corr()
plt.pcolor(plt_corr)
plt.xticks(np.arange())
plt.colorbar()
plt.show()

# %% [raw]
# - pandas의 함수들을 이용하여 다음을 수행하시오.

# %%
import pandas as pd

# %% [raw]
# 9.‘medv’값에 대한 히스토그램을 그리시오.

# %%
boston_df['medv'].plot.hist()
plt.show()

# %% [raw]
# 10. ‘medv’값에 대한 박스플랏을 그리시오.

# %%
boston_df[['medv']].boxplot()
# Out:
# <Axes: >

# %% [raw]
# 11.‘chas’값에 대한 바 차트를 그리시오.

# %%
boston_df['chas'].value_counts().plot.bar()
plt.show()

# %% [raw]
# !! 12.‘chas’별로 ‘medv’ 값에 대한 박스 플랏을 그리시오.

# %%
boston_df[['chas', 'medv']].boxplot(by='chas')
# Out:
# <Axes: title={'center': 'medv'}, xlabel='[chas]'>

# %% [raw]
# 13. x축을 ‘crim’, y축을 ‘medv’로 해서 산점도를 그리시오.

# %%
boston_df.plot.scatter(x='crim', y='medv')
# Out:
# <Axes: xlabel='crim', ylabel='medv'>

# %% [raw]
# 14.‘medv’값을 레코드 순으로 라인 차트를 그리시오.

# %%
boston_df['medv'].plot.line()
# Out:
# <Axes: >

# %% [raw]
# !! 15. 전체 변수들에 대한 히트맵을 그리시오.

# %%
pd_corr = boston_df.corr()
pd_corr.style.background_gradient(cmap='coolwarm').set_properties(**{'font-size': '0pt'})
# Out:
# <style type="text/css">
# #T_ed66b_row0_col0, #T_ed66b_row1_col1, #T_ed66b_row2_col2, #T_ed66b_row3_col3, #T_ed66b_row4_col4, #T_ed66b_row5_col5, #T_ed66b_row6_col6, #T_ed66b_row7_col7, #T_ed66b_row8_col8, #T_ed66b_row9_col9, #T_ed66b_row10_col10, #T_ed66b_row11_col11, #T_ed66b_row12_col12, #T_ed66b_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_ed66b_row0_col1 {
#   background-color: #88abfd;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_ed66b_row0_col2 {
#   background-color: #f7bca1;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_ed66b_row0_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_ed66b_row0_col4 {
#   background-color: #f7b599;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_ed66b_row0_col5 {
#   background-color: #8badfd;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_ed66b_row0_col6, #T_ed66b_row1_col13 {
#   background-color: #f5c2aa;
#   color: #000000;
#   font-size: 0pt;
# ...

# %% [raw]
# - seaborn 패키지를 이용하여 다음을 수행하시오.

# %% [raw]
# 16.‘medv’값에 대한 히스토그램을 그리시오.

# %%
import seaborn as sns
sns.histplot(data=boston_df['medv'])
# Out:
# <Axes: xlabel='medv', ylabel='Count'>

# %% [raw]
# !! 17.‘medv’값에 대한 박스플랏을 그리시오.

# %%
sns.boxplot(data=boston_df, y='medv')
# Out:
# <Axes: ylabel='medv'>

# %% [raw]
# !! 18.‘chas’값에 대한 바 차트를 그리시오.

# %%
sns.countplot(data=boston_df, x='chas')
# Out:
# <Axes: xlabel='chas', ylabel='count'>

# %% [raw]
# 19.‘chas’별로 ‘medv’ 값에 대한 박스 플랏을 그리시오.

# %%
sns.boxplot(data=boston_df, x='chas', y='medv')
# Out:
# <Axes: xlabel='chas', ylabel='medv'>

# %% [raw]
# 20. x축을 ‘crim’, y축을 ‘medv’로 해서 산점도를 그리시오.

# %%
sns.scatterplot(data=boston_df, x='crim', y='medv')
plt.show()

# %% [raw]
# !! 21. x축을 ‘crim’, y축을 ‘medv’로 해서 산점도를 그리시오. 단 chas 값별로 다른 색으로 표시하시오.

# %%
sns.scatterplot(x='crim', y='medv', data=boston_df, hue='chas')
# Out:
# <Axes: xlabel='crim', ylabel='medv'>

# %% [raw]
# !! 22.‘medv’값을 레코드 순으로 라인 차트를 그리시오.

# %%
sns.lineplot(data=boston_df['medv'])
# Out:
# <Axes: ylabel='medv'>

# %% [raw]
# 23. 전체 변수들에 대한 히트맵을 그리시오.

# %%
corr = boston_df.corr()
sns.set(rc= {'figure.figsize': (15, 8)})
sns.heatmap(data=corr, annot=True)
# Out:
# <Axes: >
